# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('..\\data\\processed\\regressor_to_matricula_SMART_complete.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7459 entries, 0 to 7458
# Data columns (total 9 columns):
# oppo_id                    7459 non-null object
# asesor_id                  7459 non-null object
# idcurso                    7459 non-null int64
# rating                     7459 non-null object
# ciudad                     7459 non-null object
# pais                       7459 non-null object
# tipo                       7459 non-null object
# days_since_modification    7459 non-null float64
# Result                     7459 non-null bool
# dtypes: bool(1), float64(1), int64(1), object(6)
# memory usage: 473.5+ KB

# %%
df['asesor_id'] = df.asesor_id.astype('category')

df['idcurso'] = df.idcurso.astype('category')
#smart['prkt_ciudades_id_c'] = smart.prkt_ciudades_id_c.astype('category')
df['prkt_paises_id1_c'] = df.prkt_paises_id1_c.astype('category')
df['ciudad'] = df.prkt_paises_id1_c.astype('category')
df['rating'] = df.rating.astype('category')
df['tipo'] = df.tipo.astype('category')
df['status'] = df.status.astype('category')
df.ciudad.fillna(method='ffill', inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7459 entries, 0 to 7458
# Data columns (total 11 columns):
# oppo_id                    7459 non-null object
# status                     7459 non-null category
# asesor_id                  7459 non-null category
# idcurso                    7459 non-null category
# rating                     7459 non-null category
# prkt_paises_id1_c          7441 non-null category
# tipo                       7459 non-null category
# Result                     7459 non-null bool
# days_since_modification    7459 non-null float64
# ciudad                     7459 non-null category
# nivel_educativo            7459 non-null object
# dtypes: bool(1), category(7), float64(1), object(2)
# memory usage: 242.9+ KB

# %%
df.prkt_paises_id1_c.value_counts()
# Out:
# EC    3754
# CO    2294
# ES     625
# PE     140
# MX     105
# CR      62
# AR      61
# DO      52
# VE      49
# SV      47
# CL      26
# PY      25
# GT      23
# BO      22
# US      18
# UY      17
# DE      15
# NI      14
# IE       9
# HN       8
# BR       8
# PA       7
# CH       6
# CU       5
# PT       4
# GB       3
# AD       3
# DK       3
# AO       3
# NL       3
# FR       3
# HT       3
# AU       2
# GQ       2
# PR       2
# CA       2
# AE       1
# ZA       1
# CV       1
# CZ       1
# ET       1
# IL       1
# IT       1
# JM       1
# JP       1
# KR       1
# LU       1
# MZ       1
# PL       1
# RU       1
# SN       1
# 0        1
# Name: prkt_paises_id1_c, dtype: int64

# %%
# Out:
#                                    oppo_id       education_level_c  \
# 464   ff1babf2-6a87-11e9-aecc-005056ab32f0              licenciado
# 891   f11c6a94-1e3f-11e9-bef6-005056ab32f0                graduado
# 1432  e05b657a-390b-11e9-a8ec-005056ab32f0  profesional_licenciado
# 1664  3a9bf87c-0466-11e9-bc6b-005056ab32f0              licenciado
# 1683  04b71dd8-030b-11e9-b050-005056ab32f0              licenciado
# 1841  1af802cc-2ea5-11e9-a70c-005056ab32f0            tercer_nivel
# 2183  66d3b568-09e5-11e9-a832-005056ab32f0            tercer_nivel
# 2488  246ee718-2733-11e9-88a6-005056ab32f0              licenciado
# 2542  d9248012-2fd7-11e9-9c4a-005056ab32f0   ingeniero_profesional
# 3022  66bc76f6-16cd-11e9-9ff8-005056ab32f0                graduado
# 3528  bca77f7c-4b19-11e9-8543-005056ab32f0               ingeniero
# 4603  358b1ba4-4180-11e9-ba1f-005056ab32f0            tercer_nivel
# 4838  a6ba9d8e-116c-11e9-90e4-005056ab32f0               postgrado
# ...

# %%
df = pd.DataFrame({'num_legs': [2, 4, 8, 0],
...                    'num_wings': [2, 0, 0, 0],
...                    'num_specimen_seen': [10, 2, 1, 8]},
...                   index=['falcon', 'dog', 'spider', 'fish'])

# %%
df.sample(n = 20, replace = False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-48-ce57e9c4072e> in <module>()
# ----> 1 df.sample(n = 20, replace = False)
#
# C:\Anaconda3\lib\site-packages\pandas\core\generic.py in sample(self, n, frac, replace, weights, random_state, axis)
#    4199                              "provide positive value.")
#    4200
# -> 4201         locs = rs.choice(axis_length, size=n, replace=replace, p=weights)
#    4202         return self.take(locs, axis=axis, is_copy=False)
#    4203
#
# mtrand.pyx in mtrand.RandomState.choice()
#
# ValueError: Cannot take a larger sample than population when 'replace=False'

# %%
from sklearn.metrics import log_loss
import numpy as np

# %%
y_pre = np.array([0.9,0.9,0.9,0.9,0.9,0.9,0.9,0.9,0.9,0.99999999])
y_real = np.array([1,1,1,1,1,1,1,1,1,0])
log_loss(y_real,y_pre )
# Out:
# 1.9368925379848043

# %%
import keras
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-56-88d96843a926> in <module>()
# ----> 1 import keras
#
# ModuleNotFoundError: No module named 'keras'

# %%
keras.losses.binary_crossentropy(y_true, y_pred)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-55-fe1c8de60384> in <module>()
# ----> 1 keras.losses.binary_crossentropy(y_true, y_pred)
#
# NameError: name 'keras' is not defined
